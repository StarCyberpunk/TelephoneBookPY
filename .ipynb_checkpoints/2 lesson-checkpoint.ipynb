# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.marital.value_counts() / len(df)
# Out:
# marital
# married     0.601933
# single      0.282896
# divorced    0.115171
# Name: count, dtype: float64

# %%
df[(df.poutcome == 'unknown')].isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df.marital.unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
df.marital.describe()
# Out:
# count       45211
# unique          3
# top       married
# freq        27214
# Name: marital, dtype: object

# %%
df.marital.value_counts()
# Out:
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64

# %% [markdown]
# df.age.hist()

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'balance'}>,
#         <Axes: title={'center': 'day'}>],
#        [<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'campaign'}>,
#         <Axes: title={'center': 'pdays'}>],
#        [<Axes: title={'center': 'previous'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
selected_data = df.loc[df['age'] < 40]

# %%
selected_data2 = selected_data.loc[df['balance'] < 420]

# %%
selected_data3 = selected_data2.loc[df['pdays'] != -1]

# %%
selected_data4=selected_data3.loc[df['contact'] != 'unknown']

# %%
selected_data5=selected_data4.loc[df['marital'] == 'married']

# %%
selected_data5
# Out:
#        age           job  marital  education default  balance housing loan  \
# 24077   36    management  married   tertiary      no        0     yes   no
# 24253   39        admin.  married  secondary      no      401     yes   no
# 24257   37    management  married   tertiary     yes        0      no   no
# 24327   30    management  married   tertiary      no      101     yes   no
# 24490   35  entrepreneur  married  secondary      no       24     yes   no
# ...    ...           ...      ...        ...     ...      ...     ...  ...
# 45149   38    technician  married   tertiary      no       88      no   no
# 45160   35    technician  married  secondary      no        0     yes   no
# 45178   34   blue-collar  married  secondary      no      320     yes   no
# 45182   34    technician  married  secondary      no      133      no   no
# 45190   32   blue-collar  married  secondary      no      136      no   no
#
# ...

# %% [markdown]
#  911 - количество людей которые младше 40, имеющие баланс меньше 420 долларов, которые обращались в этом году,которые имеют контактные данные, и которые состоят в браке

# %%
grouped_data = df.loc[df['job'] != 'unknown'].groupby('job').count()
grouped_data
# Out:
#                 age  marital  education  default  balance  housing  loan  \
# job
# admin.         5171     5171       5171     5171     5171     5171  5171
# blue-collar    9732     9732       9732     9732     9732     9732  9732
# entrepreneur   1487     1487       1487     1487     1487     1487  1487
# housemaid      1240     1240       1240     1240     1240     1240  1240
# management     9458     9458       9458     9458     9458     9458  9458
# retired        2264     2264       2264     2264     2264     2264  2264
# self-employed  1579     1579       1579     1579     1579     1579  1579
# services       4154     4154       4154     4154     4154     4154  4154
# student         938      938        938      938      938      938   938
# technician     7597     7597       7597     7597     7597     7597  7597
# unemployed     1303     1303       1303     1303     1303     1303  1303
#
#                contact   day  month  duration  campaign  pdays  previous  \
# job
# ...

# %%
grouped_data2 = df.groupby('marital').count()
grouped_data2
# Out:
#             age    job  education  default  balance  housing   loan  contact  \
# marital
# divorced   5207   5207       5207     5207     5207     5207   5207     5207
# married   27214  27214      27214    27214    27214    27214  27214    27214
# single    12790  12790      12790    12790    12790    12790  12790    12790
#
#             day  month  duration  campaign  pdays  previous  poutcome      y
# marital
# divorced   5207   5207      5207      5207   5207      5207      5207   5207
# married   27214  27214     27214     27214  27214     27214     27214  27214
# single    12790  12790     12790     12790  12790     12790     12790  12790

# %%
df[['education', 'age']].groupby(['education']).agg(lambda x: x.max() - x.min())
# Out:
#            age
# education
# primary     77
# secondary   77
# tertiary    69
# unknown     75

# %%
df[['job', 'age']].groupby(['job']).agg(lambda x: x.max() - x.min())
# Out:
#                age
# job
# admin.          55
# blue-collar     55
# entrepreneur    63
# housemaid       61
# management      60
# retired         71
# self-employed   54
# services        49
# student         30
# technician      50
# unemployed      45
# unknown         57
